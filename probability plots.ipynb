# %%
from scipy.stats import zscore
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
def npp(data):
 data=sorted(data)
 p=[(data.index(i)-0.5)/len(data) for i in data]
 z=zscore(p)
 plt.scatter(data,z)
 plt.ylabel("Z VALUES")
 plt.xlabel("values")
 plt.show()
 plt.plot(data,z,"ro",data,data)
 plt.show()
n=88
data=np.random.randn(n)
npp(data)

# %%
x1=[3.01,3.35,4.79,5.96,7.89]
x2=[3.89,4.75,4.75,5.20,5.78,5.80,6.33,7.21,7.99]
x3=[100.047,109.249,103.385,112.454,95.784,88.92,123.784,119.67,114.37]
def npp1(data):
 p=[]
 t=[]
 data=np.sort(np.array(data))
 p=[(i-0.5)/len(data) for i in range(1,len(data)+1)]
 t=[norm.ppf(i,np.mean(data),np.std(data)) for i in p]
 plt.plot(data,t,"go",data,data)
 plt.show()
npp1(x1)
npp1(x2)
npp1(x3)
